# %%
import pandas as pd
import numpy as np

# %%
dist_retas = pd.read_excel('https://github.com/tnpb-1st/if684-projeto-busca-estrela/blob/master/direct-distances.xlsx?raw=true', index_col=0)
dist_estacoes = pd.read_excel('https://github.com/tnpb-1st/if684-projeto-busca-estrela/blob/master/station-distances.xlsx?raw=true',index_col=0)

# %%
dist_retas
# Out:
#           E1          E2        E3          E4          E5      E6  \
# E1       NaN     10-blue       NaN         NaN         NaN     NaN
# E2   10-blue         NaN  8,5-blue         NaN         NaN     NaN
# E3       NaN    8,5-blue       NaN    6,3-blue         NaN     NaN
# E4       NaN         NaN  6,3-blue         NaN     13-blue     NaN
# E5       NaN         NaN       NaN     13-blue         NaN  3-blue
# E6       NaN         NaN       NaN         NaN      3-blue     NaN
# E7       NaN         NaN       NaN         NaN  2,4-yellow     NaN
# E8       NaN         NaN       NaN  15,3-green   30-yellow     NaN
# E9       NaN   10-yellow   9,4-red         NaN         NaN     NaN
# E10      NaN  3,5-yellow       NaN         NaN         NaN     NaN
# E11      NaN         NaN       NaN         NaN         NaN     NaN
# E12      NaN         NaN       NaN         NaN         NaN     NaN
# E13      NaN         NaN  18,7-red  12,8-green         NaN     NaN
# ...

# %%
df_direto = dist_estacoes.copy(deep=True)
for r in df_direto.index:
  df_direto.loc[r, df_direto[r].notnull()] = df_direto.loc[r, df_direto[r].notnull()].apply(lambda t : float(t.split('-')[0].replace(',', '.'))*2)
  df_direto.loc[r, df_direto[r].isnull()] = None
df_direto
# Out:
#        E1    E2    E3    E4    E5    E6    E7    E8    E9   E10   E11   E12  \
# E1   None  20.0  None  None  None  None  None  None  None  None  None  None
# E2   20.0  None  17.0  None  None  None  None  None  20.0   7.0  None  None
# E3   None  17.0  None  12.6  None  None  None  None  18.8  None  None  None
# E4   None  None  12.6  None  26.0  None  None  30.6  None  None  None  None
# E5   None  None  None  26.0  None   6.0   4.8  60.0  None  None  None  None
# E6   None  None  None  None   6.0  None  None  None  None  None  None  None
# E7   None  None  None  None   4.8  None  None  None  None  None  None  None
# E8   None  None  None  30.6  60.0  None  None  None  19.2  None  None  12.8
# E9   None  20.0  18.8  None  None  None  None  19.2  None  None  24.4  None
# E10  None   7.0  None  None  None  None  None  None  None  None  None  None
# E11  None  None  None  None  None  None  None  None  24.4  None  None  None
# ...

# %%
# dist_retas

# %%
# dist_retas.index

# %%
def make_stations_dic(dist_estacoes):
  # Dado que B = Linha Blue, Y = Linha Yellow, G = Linha Green, R = Linha Red;
  dici = {}
  for ind in dist_estacoes.index:
    for col in dist_estacoes.columns:
      if type(dist_estacoes.loc[ind,col]) != type(np.nan):
        e1, e2 = ind, col
        dist,line = dist_estacoes.loc[ind,col].split('-')
        dist = float(dist.replace(',','.'))
        if line == 'yellow':
          line = 'Y'
        elif line == 'green':
          line = 'G'
        elif line == 'blue':
          line = 'B'
        else:
          line = 'R'
        if e1 not in dici:
          dici[e1] = {e2: (dist, line)}
        else:
          dici[e1][e2] = (dist, line)
        if e2 not in dici:
          dici[e2] = {e1 : (dist, line)}
        else:
          dici[e2][e1] = (dist, line)
  return dici

# %%
class BinaryHeap:
  def _swap(self, i, j):
    self._container[i], self._container[j] = self._container[j], self._container[i]

  def _parent(self, i):
    return (i - 1) // 2
  
  def _left(self, i):
    return 2 * i + 1

  def _right(self, i):
    return 2 * i + 2

  def _has_left(self, i):
    return self._left(i) < self._size
  
  def _has_right(self, i):
    return self._right(i) < self._size
  
  def _upheap(self, i):
    parent = self._parent(i)
    if i > 0 and self._container[i][0] < self._container[parent][0]:
      self._swap(i, parent)
      self._upheap(parent)
  
  def _downheap(self, i):
    if self._has_left(i):
      left = self._left(i)
      small_child = left
      if self._has_right(i):
        right = self._right(i)
        if self._container[right][0] < self._container[left][0]:
          small_child = right
      if self._container[small_child][0] < self._container[i][0]:
        self._swap(i, small_child)
        self._downheap(small_child)
  
  def __init__(self):
    self._container = []
    self._size = 0
  
  def push(self, est:tuple):
    self._container.append(est)
    self._size += 1
    self._upheap(self._size - 1)

  def extract_min(self):
    if self._size == 0:
      raise IndexError('Empty Heap!')
    self._swap(0, self._size - 1)
    return_value = self._container.pop()
    self._size -= 1
    self._downheap(0)
    return return_value
  
  def build_heap(self, alist:list):
    i = len(alist) // 2
    self._size = len(alist)
    self._container = alist[:]
    while (i >= 0):
        self._downheap(i)
        i = i - 1
  
  def empty(self)->bool:
    return self._size == 0
  
  def __len__(self):
    return self._size
  
  def __str__(self):
    return str(self._container)
  
  def __repr__(self):
    return str(self._container)
  
  def clear(self):
    self._container = []
    self._size = 0

# %%
def distancia_para_tempo_em_minutos(distancia_km):
  return distancia_km * 2

# %%
class Mapa:
  def __init__(self, est_ini, linha_ini, est_fin):
    self.dist_real = make_stations_dic(dist_estacoes)
    self.dist_heuristica = {
        'E1' :{
            'E1' : 0,
            'E2' : 10,
            'E3' : 18.5,
            'E4' : 24.8,
            'E5' : 36.4,
            'E6' : 38.8,
            'E7' : 35.8,
            'E8' : 25.4,
            'E9' : 17.6,
            'E10' : 9.1,
            'E11' : 16.7,
            'E12' : 27.3,
            'E13' : 27.6,
            'E14' : 29.8
            
        },
        'E2' :{
            'E1' : 10,
            'E2' : 0,
            'E3' : 8.5,
            'E4' : 14.8,
            'E5' : 26.6,
            'E6' : 29.1,
            'E7' : 26.1,
            'E8' : 17.3,
            'E9' : 10,
            'E10' : 3.5,
            'E11' : 15.5,
            'E12' : 20.9,
            'E13' : 19.1,
            'E14' : 21.8
            },

        'E3' :{
            'E1' : 18.5,
            'E2' : 8.5,
            'E3' : 0,
            'E4' : 6.3,
            'E5' : 18.2,
            'E6' : 20.6,
            'E7' : 17.6,
            'E8' : 13.6,
            'E9' : 9.4,
            'E10' : 10.3,
            'E11' : 19.5,
            'E12' : 19.1,
            'E13' : 12.1,
            'E14' : 16.6
            },
        'E4'  :{
            'E1' : 24.8,
            'E2' : 14.8,
            'E3' : 6.3,
            'E4' : 0,
            'E5' : 12,
            'E6' : 14.4,
            'E7' : 11.5,
            'E8' : 12.4,
            'E9' : 12.6,
            'E10' : 16.7,
            'E11' : 23.6,
            'E12' : 18.6,
            'E13' : 10.6,
            'E14' : 15.4
        },

        'E5'  :{
            'E1' : 36.4,
            'E2' : 26.6,
            'E3' : 18.2,
            'E4' : 12,
            'E5' : 0,
            'E6' : 3,
            'E7' : 2.4,
            'E8' : 19.4,
            'E9' : 23.3,
            'E10' : 28.2,
            'E11' : 34.2,
            'E12' : 24.8,
            'E13' : 14.5,
            'E14' : 17.9
            
        },   
        'E6'  :{
            'E1' : 38.8,
            'E2' : 29.1,
            'E3' : 20.6,
            'E4' : 14.4,
            'E5' : 3,
            'E6' : 0,
            'E7' : 3.3,
            'E8' : 22.3,
            'E9' : 25.7,
            'E10' : 30.3,
            'E11' : 36.7,
            'E12' : 27.6,
            'E13' : 15.2,
            'E14' : 18.2
            
        },    
        'E7'  :{
            'E1' : 35.8,
            'E2' : 26.1,
            'E3' : 17.6,
            'E4' : 11.5,
            'E5' : 2.4,
            'E6' : 3.3,
            'E7' : 0,
            'E8' : 20,
            'E9' : 23,
            'E10' : 27.3,
            'E11' : 34.2,
            'E12' : 25.7,
            'E13' : 12.4,
            'E14' : 15.6

        },    
        'E8'  :{
            'E1' : 25.4,
            'E2' : 17.3,
            'E3' : 13.6,
            'E4' : 12.4,
            'E5' : 19.4,
            'E6' : 22.3,
            'E7' : 20,
            'E8' : 0,
            'E9' : 8.2,
            'E10' : 20.3,
            'E11' : 16.1,
            'E12' : 6.4,
            'E13' : 22.7,
            'E14' : 27.6

        },    
        'E9'  :{
            'E1' : 17.6,
            'E2' : 10,
            'E3' : 9.4,
            'E4' : 12.6,
            'E5' : 23.3,
            'E6' : 25.7,
            'E7' : 23,
            'E8' : 8.2,
            'E9' : 0,
            'E10' : 13.5,
            'E11' : 11.2,
            'E12' : 10.9,
            'E13' : 21.2,
            'E14' : 26.6
        },

        'E10'  :{
            'E1' : 9.1,
            'E2' : 3.5,
            'E3' : 10.3,
            'E4' : 16.7,
            'E5' : 28.2,
            'E6' : 30.3,
            'E7' : 27.3,
            'E8' : 20.3,
            'E9' : 13.5,
            'E10' : 0,
            'E11' : 17.6,
            'E12' : 24.2,
            'E13' : 18.7,
            'E14' : 21.2
        },
        
        'E11'  :{
            'E1' : 16.7,
            'E2' : 15.5,
            'E3' : 19.5,
            'E4' : 23.6,
            'E5' : 34.2,
            'E6' : 36.7,
            'E7' : 34.2,
            'E8' : 16.1,
            'E9' : 11.2,
            'E10' : 17.6,
            'E11' : 0,
            'E12' : 14.2,
            'E13' : 31.5,
            'E14' : 35.5,
        },
        
        'E12'  :{
            'E1' : 27.3,
            'E2' : 20.9,
            'E3' : 19.1,
            'E4' : 18.6,
            'E5' : 24.8,
            'E6' : 27.6,
            'E7' : 25.7,
            'E8' : 6.4,
            'E9' : 10.9,
            'E10' : 24.2,
            'E11' : 14.2,
            'E12' : 0,
            'E13' : 28.6,
            'E14' : 33.6,
            },
        'E13'  :{
            'E1' : 27.6,
            'E2' : 19.1,
            'E3' : 12.1,
            'E4' : 10.6,
            'E5' : 14.5,
            'E6' : 15.2,
            'E7' : 12.4,
            'E8' : 22.7,
            'E9' : 21.2,
            'E10' : 18.7,
            'E11' : 31.5,
            'E12' : 28.8,
            'E13' : 0,
            'E14' : 5.1,
            },
        'E14'  :{
            'E1' : 29.8,
            'E2' : 21.8,
            'E3' : 16.6,
            'E4' : 15.4,
            'E5' : 17.9,
            'E6' : 18.2,
            'E7' : 15.6,
            'E8' : 27.6,
            'E9' : 26.6,
            'E10' : 21.2,
            'E11' : 35.5,
            'E12' : 33.6,
            'E13' : 5.1,
            'E14' : 0,
        }
    }

    self.linhas_possiveis = {
        'E1':{'B'},  
        'E2': {'B','Y'},
        'E3': {'B','R'},
        'E4': {'B','G'},
        'E5': {'B','Y'}        ,
        'E6': {'B'},
        'E7': {'Y'},
        'E8': {'B','Y'},
        'E9': {'R','Y'},
        'E10': {'Y'},
        'E11': {'R'},
        'E12': {'G'},
        'E13': {'G','R'},
        'E14': {'G'}
    }
    INF = int(2e9)
    self.grid = {station: {"g": INF, "f": INF, "est_pai": None, "visitado": False} for station in dist_retas.index}

    self.linhas_percorridas = []
    self.est_to_idx = {}
    for i,est in enumerate(dist_retas.index):
      self.est_to_idx[est] = i
    self.est_ini = est_ini
    self.linha_ini = linha_ini
    self.est_fin = est_fin

  def calcula_custo_real(self, est_atual, custo_atual, linha_atual, est_vizinha, est_final):
    dist_para_vizinha, linha = self.dist_real[est_atual][est_vizinha]
    # print(f"{est_atual} -> {est_vizinha}: {dist_para_vizinha=}")
    tempo_para_vizinha = distancia_para_tempo_em_minutos(dist_para_vizinha)
  
    tempo_troca_de_linha = 0
    if linha != linha_atual:
      tempo_troca_de_linha += 4
      linha_atual = linha

    custo_real = tempo_para_vizinha + custo_atual + tempo_troca_de_linha
    # print(f"{est_atual} -> {est_vizinha}: {custo_real}")
    return custo_real, linha

def gera_fronteira(self, est):
    est_vizinhas = list(self.dist_real[est].keys())
    fronteira = est_vizinhas[:]
    for est_vizinha in est_vizinhas:
        est_visitada = self.grid[est_vizinha]['visitada']
        est_pai = self.grid[est_vizinha]['est_pai']
        if est_visitada or est_pai == est:
            fronteira.remove(est_vizinha)
    return fronteira

def atualiza_grid(self, fronteira):
    for est in fronteira:
        est_on_grid = self.grid[est]
        est_pai_on_grid = est_on_grid["est_pai"]
        g = est_pai_on_grid['g'] 



    
            





def melhor_caminho(self, est_inicial, linha_inicial, est_final):
    est_atual = est_inicial
    caminho_atual = 0
    while est_atual != est_final:
        fronteira = self.gera_fronteira(est_atual)
        est_atual = self.atualiza_grid(fronteira)
# Out:
#   Cell In[1], line 301
#     def melhor_caminho(self, est_inicial, linha_inicial, est_final):
#                                                                     ^
# IndentationError: expected an indented block after 'for' statement on line 293

# %%
mapa = Mapa('E1', 'B', "E11")

print(mapa.grid)
est_inicial, lin_inicial, est_final = 'E1', 'B', 'E11'
# caminho = mapa.calcula_melhor_caminho(est_inicial, lin_inicial, est_final)
# estacoes, tempo_total = caminho
# print(estacoes)
# itinerarios(estacoes, lin_inicial, round(tempo_total), mapa.dist_real)

# pares pra testar
# E1-E11
# E10-E12
# E7-E11
# E8-E11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 mapa = Mapa()
#       3 print(mapa.grid)
#       4 est_inicial, lin_inicial, est_final = 'E1', 'B', 'E11'
#
# TypeError: Mapa.__init__() missing 3 required positional arguments: 'est_ini', 'linha_ini', and 'est_fin'
