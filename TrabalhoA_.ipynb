# %%
import pandas as pd

# %%
dist_retas = pd.read_excel('./retas.xlsx', index_col=0)
dist_estacoes = pd.read_excel('https://github.com/tnpb-1st/if684-projeto-busca-estrela/blob/master/station-distances.xlsx?raw=true',index_col=0)

# %%
df_direto = dist_retas.copy(deep=True)
for r in df_direto.index:
  for c in df_direto.columns:
    if df_direto.loc[r,c]:
      df_direto.loc[r,c] = df_direto.loc[r,c] * 2
      df_direto.loc[c,r] = df_direto.loc[r,c]
df_direto.to_csv('retas.csv')

# %%
# dist_retas.index

# %%
class Mapa:
    def __init__(self, est_ini, linha_ini, est_fin):
        self.dist_real = make_stations_dic(dist_estacoes)
        self.dist_heuristica = {
            'E1' :{
                'E1' : 0,
                'E2' : 10,
                'E3' : 18.5,
                'E4' : 24.8,
                'E5' : 36.4,
                'E6' : 38.8,
                'E7' : 35.8,
                'E8' : 25.4,
                'E9' : 17.6,
                'E10' : 9.1,
                'E11' : 16.7,
                'E12' : 27.3,
                'E13' : 27.6,
                'E14' : 29.8
                
            },
            'E2' :{
                'E1' : 10,
                'E2' : 0,
                'E3' : 8.5,
                'E4' : 14.8,
                'E5' : 26.6,
                'E6' : 29.1,
                'E7' : 26.1,
                'E8' : 17.3,
                'E9' : 10,
                'E10' : 3.5,
                'E11' : 15.5,
                'E12' : 20.9,
                'E13' : 19.1,
                'E14' : 21.8
                },

            'E3' :{
                'E1' : 18.5,
                'E2' : 8.5,
                'E3' : 0,
                'E4' : 6.3,
                'E5' : 18.2,
                'E6' : 20.6,
                'E7' : 17.6,
                'E8' : 13.6,
                'E9' : 9.4,
                'E10' : 10.3,
                'E11' : 19.5,
                'E12' : 19.1,
                'E13' : 12.1,
                'E14' : 16.6
                },
            'E4'  :{
                'E1' : 24.8,
                'E2' : 14.8,
                'E3' : 6.3,
                'E4' : 0,
                'E5' : 12,
                'E6' : 14.4,
                'E7' : 11.5,
                'E8' : 12.4,
                'E9' : 12.6,
                'E10' : 16.7,
                'E11' : 23.6,
                'E12' : 18.6,
                'E13' : 10.6,
                'E14' : 15.4
            },

            'E5'  :{
                'E1' : 36.4,
                'E2' : 26.6,
                'E3' : 18.2,
                'E4' : 12,
                'E5' : 0,
                'E6' : 3,
                'E7' : 2.4,
                'E8' : 19.4,
                'E9' : 23.3,
                'E10' : 28.2,
                'E11' : 34.2,
                'E12' : 24.8,
                'E13' : 14.5,
                'E14' : 17.9
                
            },   
            'E6'  :{
                'E1' : 38.8,
                'E2' : 29.1,
                'E3' : 20.6,
                'E4' : 14.4,
                'E5' : 3,
                'E6' : 0,
                'E7' : 3.3,
                'E8' : 22.3,
                'E9' : 25.7,
                'E10' : 30.3,
                'E11' : 36.7,
                'E12' : 27.6,
                'E13' : 15.2,
                'E14' : 18.2
                
            },    
            'E7'  :{
                'E1' : 35.8,
                'E2' : 26.1,
                'E3' : 17.6,
                'E4' : 11.5,
                'E5' : 2.4,
                'E6' : 3.3,
                'E7' : 0,
                'E8' : 20,
                'E9' : 23,
                'E10' : 27.3,
                'E11' : 34.2,
                'E12' : 25.7,
                'E13' : 12.4,
                'E14' : 15.6

            },    
            'E8'  :{
                'E1' : 25.4,
                'E2' : 17.3,
                'E3' : 13.6,
                'E4' : 12.4,
                'E5' : 19.4,
                'E6' : 22.3,
                'E7' : 20,
                'E8' : 0,
                'E9' : 8.2,
                'E10' : 20.3,
                'E11' : 16.1,
                'E12' : 6.4,
                'E13' : 22.7,
                'E14' : 27.6

            },    
            'E9'  :{
                'E1' : 17.6,
                'E2' : 10,
                'E3' : 9.4,
                'E4' : 12.6,
                'E5' : 23.3,
                'E6' : 25.7,
                'E7' : 23,
                'E8' : 8.2,
                'E9' : 0,
                'E10' : 13.5,
                'E11' : 11.2,
                'E12' : 10.9,
                'E13' : 21.2,
                'E14' : 26.6
            },

            'E10'  :{
                'E1' : 9.1,
                'E2' : 3.5,
                'E3' : 10.3,
                'E4' : 16.7,
                'E5' : 28.2,
                'E6' : 30.3,
                'E7' : 27.3,
                'E8' : 20.3,
                'E9' : 13.5,
                'E10' : 0,
                'E11' : 17.6,
                'E12' : 24.2,
                'E13' : 18.7,
                'E14' : 21.2
            },
            
            'E11'  :{
                'E1' : 16.7,
                'E2' : 15.5,
                'E3' : 19.5,
                'E4' : 23.6,
                'E5' : 34.2,
                'E6' : 36.7,
                'E7' : 34.2,
                'E8' : 16.1,
                'E9' : 11.2,
                'E10' : 17.6,
                'E11' : 0,
                'E12' : 14.2,
                'E13' : 31.5,
                'E14' : 35.5,
            },
            
            'E12'  :{
                'E1' : 27.3,
                'E2' : 20.9,
                'E3' : 19.1,
                'E4' : 18.6,
                'E5' : 24.8,
                'E6' : 27.6,
                'E7' : 25.7,
                'E8' : 6.4,
                'E9' : 10.9,
                'E10' : 24.2,
                'E11' : 14.2,
                'E12' : 0,
                'E13' : 28.6,
                'E14' : 33.6,
                },
            'E13'  :{
                'E1' : 27.6,
                'E2' : 19.1,
                'E3' : 12.1,
                'E4' : 10.6,
                'E5' : 14.5,
                'E6' : 15.2,
                'E7' : 12.4,
                'E8' : 22.7,
                'E9' : 21.2,
                'E10' : 18.7,
                'E11' : 31.5,
                'E12' : 28.8,
                'E13' : 0,
                'E14' : 5.1,
                },
            'E14'  :{
                'E1' : 29.8,
                'E2' : 21.8,
                'E3' : 16.6,
                'E4' : 15.4,
                'E5' : 17.9,
                'E6' : 18.2,
                'E7' : 15.6,
                'E8' : 27.6,
                'E9' : 26.6,
                'E10' : 21.2,
                'E11' : 35.5,
                'E12' : 33.6,
                'E13' : 5.1,
                'E14' : 0,
            }
        }

        self.linhas_possiveis = {
            'E1':{'B'},  
            'E2': {'B','Y'},
            'E3': {'B','R'},
            'E4': {'B','G'},
            'E5': {'B','Y'},
            'E6': {'B'},
            'E7': {'Y'},
            'E8': {'B','Y'},
            'E9': {'R','Y'},
            'E10': {'Y'},
            'E11': {'R'},
            'E12': {'G'},
            'E13': {'G','R'},
            'E14': {'G'}
        }
        INF = int(2e9)
        self.grid = {station: {"f": INF, "g": INF, "h": INF, "est_pai": None, "visitado": False} for station in dist_retas.index}

        self.linhas_percorridas = []
        self.est_to_idx = {}

        for i,est in enumerate(dist_retas.index):
            self.est_to_idx[est] = i
        self.est_inicial = est_ini
        self.linha_ini = linha_ini
        self.est_final = est_fin

    def calcula_custo_real(self, est_atual, custo_atual, linha_atual, est_vizinha, est_final):
        dist_para_vizinha, linha = self.dist_real[est_atual][est_vizinha]
        # print(f"{est_atual} -> {est_vizinha}: {dist_para_vizinha=}")
        tempo_para_vizinha = distancia_para_tempo_em_minutos(dist_para_vizinha)
    
        tempo_troca_de_linha = 0
        if linha != linha_atual:
            tempo_troca_de_linha += 4
        linha_atual = linha

        custo_real = tempo_para_vizinha + custo_atual + tempo_troca_de_linha
        # print(f"{est_atual} -> {est_vizinha}: {custo_real}")
        return custo_real, linha

    def gera_fronteira(self, est):
        print(list(self.dist_real[est].keys()))
        est_vizinhas = list(self.dist_real[est].keys())
        fronteira = est_vizinhas[:]
        for est_vizinha in est_vizinhas:
            est_visitada = self.grid[est_vizinha]['visitado']
            est_pai = self.grid[est_vizinha]['est_pai']
            if est_visitada or est_pai == est:
                fronteira.remove(est_vizinha)
        return fronteira

    @staticmethod
    def calcula_f(est_no_grid):
        return est_no_grid['g'] + est_no_grid['h']


    def atualiza_grid(self, est_atual, fronteira):
        for est_fronteira in fronteira:
            est_no_grid = self.grid[est_fronteira]
            dist_para_est = self.dist_real[est_atual][est_fronteira]
            tempo_para_est = distancia_para_tempo_em_minutos(dist_para_est)[0]

            g_pai = est_no_grid["est_pai"]["g"] if est_no_grid.get("est_pai") else 0
            # print(g_pai, dist_para_est)
            g = g_pai + tempo_para_est

            h = self.dist_heuristica[est_fronteira][self.est_final]

            possivel_f = g + h
            f_atual = self.calcula_f(est_no_grid)
            if possivel_f < f_atual:
                est_no_grid['g'] = g
                est_no_grid['h'] = h
                est_no_grid['f'] = possivel_f
                est_no_grid['est_pai'] = est_atual


    def seleciona_menor_f_do_grid(self):
        menor_est = self.grid['E1']
        menor_f = menor_est['f']

        for est, values in self.grid.items():
            if values['f'] < menor_f:
                menor_f = values['f']
                menor_est = self.grid[est]
        return menor_est
    def recupera_caminho(self, est_final=None):
        if est_final is None:
            est_final = self.est_final

        est_atual = self.grid[est_final]
        caminho = []
        while est_atual.get('est_pai'):
            caminho.append(est_atual)
            est_atual = est_atual['est_pai']
        caminho.reverse()
        return caminho

    def melhor_caminho(self):
        est_atual = self.est_inicial
        while est_atual != self.est_final:
            fronteira = self.gera_fronteira(est_atual)
            self.atualiza_grid(est_atual, fronteira)
            est_atual = self.seleciona_menor_f_do_grid()
        
        caminho = self.recupera_caminho()
        return caminho

        
mapa = Mapa('E1', 'B', "E11")

print(mapa.melhor_caminho())
# Out:
# ['E2']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 354
#     349         return caminho
#     352 mapa = Mapa('E1', 'B', "E11")
# --> 354 print(mapa.melhor_caminho())
#
# Cell In[21], line 344, in Mapa.melhor_caminho(self)
#     342 est_atual = self.est_inicial
#     343 while est_atual != self.est_final:
# --> 344     fronteira = self.gera_fronteira(est_atual)
#     345     self.atualiza_grid(est_atual, fronteira)
#     346     est_atual = self.seleciona_menor_f_do_grid()
#
# Cell In[21], line 284, in Mapa.gera_fronteira(self, est)
#     283 def gera_fronteira(self, est):
# --> 284     print(list(self.dist_real[est].keys()))
#     285     est_vizinhas = list(self.dist_real[est].keys())
#     286     fronteira = est_vizinhas[:]
#
# TypeError: unhashable type: 'dict'
